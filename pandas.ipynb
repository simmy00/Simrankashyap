# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("C:/Users/Asus/.vscode/pandas/Attrition data.csv")

# %%
# reading the data 
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  DistanceFromHome  Education EducationField  EmployeeCount  Gender  JobLevel                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51        No      Travel_Rarely                   Sales                 6          2  Life Sciences              1  Female         1  Healthcare Representative       Married         131160                 1.0      Y                 11              8                 0                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
df.tail()
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  DistanceFromHome  Education EducationField  EmployeeCount  Gender  JobLevel                JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 4405        4406   42        No  Travel_Rarely  Research & Development                 5          4        Medical              1  Female         1     Research Scientist        Single          60290                 3.0      Y                 17              8                 1               10.0                      5               3                        0                     2                      4.0              1.0              3.0               3                  3
# ...

# %%
df.shape
# Out:
# (4410, 29)
# (4410, 29)

# %%
df.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount     JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0  4410.000000    4410.000000         4391.000000        4410.000000         4410.0       4410.000000        4401.000000            4410.000000     4410.000000              4410.000000           4410.000000              4385.000000      4390.000000      4372.000000     4410.000000        4410.000000
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating'], dtype='object')
# ...

# %%
df.nunique()
# Out:
# EmployeeID                 4410
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# EnvironmentSatisfaction       4
# JobSatisfaction               4
# WorkLifeBalance               4
# JobInvolvement                4
# PerformanceRating             2
# ...

# %%
df['Education'].unique()
# Out:
# array([2, 1, 4, 5, 3], dtype=int64)
# array([2, 1, 4, 5, 3], dtype=int64)

# %%
df['JobRole'].unique()
# Out:
# array(['Healthcare Representative', 'Research Scientist',
#        'Sales Executive', 'Human Resources', 'Research Director',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Sales Representative', 'Manager'], dtype=object)
# array(['Healthcare Representative', 'Research Scientist',
#        'Sales Executive', 'Human Resources', 'Research Director',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Sales Representative', 'Manager'], dtype=object)

# %%
df.drop(['EmployeeCount','Over18','StandardHours','StockOptionLevel'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  DistanceFromHome  Education EducationField  Gender  JobLevel                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51        No      Travel_Rarely                   Sales                 6          2  Life Sciences  Female         1  Healthcare Representative       Married         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  DistanceFromHome  Education EducationField  Gender  JobLevel                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51        No      Travel_Rarely                   Sales                 6          2  Life Sciences  Female         1  Healthcare Representative       Married         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
# cleaning the data 
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# ...

# %%
df.shape
# Out:
# (4410, 25)
# (4410, 25)

# %%
# Assuming 'df' is your DataFrame
attrition_counts = df['Attrition'].value_counts()
 
# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(attrition_counts.index, attrition_counts, color='red')
plt.title('Count Plot of Attrition')
plt.xlabel('attrition')
plt.ylabel('Count')
plt.show()

# %%
df = df.dropna(subset=['NumCompaniesWorked', 'EnvironmentSatisfaction' , 'JobSatisfaction' ,'WorkLifeBalance' , 'TotalWorkingYears'])

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# ...

# %%
df_no_duplicates = df.drop_duplicates()

# %%
duplicates_count = df.duplicated().sum()

# %%
print(duplicates_count)
# Out:
# 0
# 0

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# PercentSalaryHike          0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# ...

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  DistanceFromHome  Education EducationField  Gender  JobLevel                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51        No      Travel_Rarely                   Sales                 6          2  Life Sciences  Female         1  Healthcare Representative       Married         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     3605
# Yes     695
# Name: count, dtype: int64
# Attrition
# No     3605
# Yes     695
# Name: count, dtype: int64

# %%
# here is the count of employees that are stayed and left the company 
sns.countplot(x='Attrition', data=df)

# Add labels and title
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.title('Count of Attrition')

# Show the plot
plt.show()

# %%
# here is the count of attrition by their age 
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', hue='Attrition', data=df, palette='colorblind', linewidth=2)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Count of Attrition by Age')

# Show the plot
plt.show()

# %%
# Attrition w.r.t Business Travel 

import pandas as pd
import seaborn as sns
from scipy.stats import chi2_contingency

# Step 1: Load your dataset


# Step 2: Data Visualization
sns.countplot(x='BusinessTravel', hue='Attrition', data=df)

# Step 3: Statistical Test
# Chi-square test for attrition and BusinessTravel
contingency_table = pd.crosstab(df['Attrition'], df['BusinessTravel'])
chi2, p, _, _ = chi2_contingency(contingency_table)
print("Chi-square test p-value for attrition and BusinessTravel:", p)
# Out:
# Chi-square test p-value for attrition and BusinessTravel: 5.097055600861411e-15
# Chi-square test p-value for attrition and BusinessTravel: 5.097055600861411e-15

# %%
#  Attrition w.r.t to Distance from home 

import pandas as pd
import seaborn as sns
from scipy.stats import ttest_ind

# Step 1: Load your dataset


# Step 2: Data Visualization
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df)

# Step 3: Statistical Test
# Perform t-test to compare DistanceFromHome for employees with and without attrition
attrition_yes = df[df['Attrition'] == 'Yes']['DistanceFromHome']
attrition_no = df[df['Attrition'] == 'No']['DistanceFromHome']
t_statistic, p_value = ttest_ind(attrition_yes, attrition_no)
print("T-test p-value for attrition and DistanceFromHome:", p_value)
# Out:
# T-test p-value for attrition and DistanceFromHome: 0.5857262212670618
# T-test p-value for attrition and DistanceFromHome: 0.5857262212670618

# %%
# now we are Analaysing the attrition w.r.t Rating Features

#JobSatisfaction
#EnvironmentSatisfaction
#Joblevel 
#JobInvolvement
#WorkLifeBalance
#PerformanceRating


df['JobSatisfaction'].value_counts()
# Out:
# JobSatisfaction
# 4.0    1334
# 3.0    1296
# 1.0     847
# 2.0     823
# Name: count, dtype: int64
# JobSatisfaction
# 4.0    1334
# 3.0    1296
# 1.0     847
# 2.0     823
# Name: count, dtype: int64

# %%
fig = plt.figure() 

ax1 = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)  
ax3 = fig.add_subplot(223) 
ax4 = fig.add_subplot(224) 


labels = 'Low','Medium','High','Very High'

df['JobSatisfaction'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax1) # add to subplot 2
ax1.set_title ('Rating of Job Satisfaction by Employees')
fig.legend(labels=labels,loc='center')

df['EnvironmentSatisfaction'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax2) 
ax2.set_title('Rating of Environmental Satisfaction by Employees')

df['JobLevel'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax3)
ax3.set_title('Rating of Joblevel by Employees')

df['JobInvolvement'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax4) 
ax4.set_title('Rating of Job Involvement by Employees')

plt.show()

# %%
fig2 = plt.figure() 

ax5 = fig2.add_subplot(121) 
ax6 = fig2.add_subplot(122)  
  
labels_list1 = 'Bad','Good','Better','Best', 'Excellent'
labels_list2 = 'Low','Good','Excellent','Outstanding'

df['WorkLifeBalance'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax5) # add to subplot 2
ax5.set_title ('Rating of Work-Life Balance by Employees')
ax5.legend(labels=labels_list1,loc='upper right')

df['PerformanceRating'].astype(str).value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,ax=ax6) 
ax6.set_title('Performance Rating of the Employees')
ax6.legend(labels=labels_list2,loc='upper right')

plt.show()

# %%
# Now we do Analysis w.r.t Work Experience

#YearsAtCompany
#YearsSinceLastPromotion
#YearsWithCurrManager
#TotalWorkingYears

work_experience = df[['YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'TotalWorkingYears', 'Attrition']]
work_experience.head()
# Out:
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  TotalWorkingYears Attrition
# 0               1                        0                     0                1.0        No
# 1               5                        1                     4                6.0       Yes
# 2               5                        0                     3                5.0        No
# 3               8                        7                     5               13.0        No
# 4               6                        0                     4                9.0        No
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  TotalWorkingYears Attrition
# 0               1                        0                     0                1.0        No
# 1               5                        1                     4                6.0       Yes
# 2               5                        0                     3                5.0        No
# ...

# %%
years_at_company = df.groupby("YearsAtCompany")['Attrition'].value_counts(normalize=False).unstack()

years_at_company.plot(kind='bar', stacked='False',figsize=(10,6))

plt.title('Years At Company of Employee')
plt.ylabel('Number of Employees')
plt.show()

# %%
#It is observed that the newly arriving employees quit their jobs most,so more concern should be given to the freshers and their cause of leaving the company should be figured out

# %%
years_sincelast_promotion = df.groupby("YearsSinceLastPromotion")['Attrition'].value_counts(normalize=False).unstack()



fig = plt.figure() # create figure

ax0 = fig.add_subplot(121) # add subplot 1 (1 row, 2 columns, first plot)


# Subplot 1: Box plot
years_sincelast_promotion.plot(kind='bar', stacked='False',figsize=(20,6), ax=ax0) # add to subplot 1
ax0.set_title('Last Promotion')
ax0.set_ylabel('Number of Employees')
ax0.set_xlabel('Years Since Last Promotion')




plt.show()

# %%
#From the above plots, it is very clear that Employees who are not getting promoted tend to leave the company most. It is a major concern, since experienced Employees quiting their jobs would affect the company most

# %%
years_with_curr_manager = df.groupby("YearsWithCurrManager")['Attrition'].value_counts(normalize=False).unstack()

years_with_curr_manager.plot(kind='bar', stacked='False',figsize=(10,6))

plt.title('Years with Current Manager')
plt.ylabel('Number of Employee')
plt.show()

# %%
# It is clear that in the starting of relation of Manager and Employee's are not so happy. It is important that the Manager communication with the employee from the starting itself trying to understand them soon to reduce the increase in Attrition

# %%
total_working_years = df.groupby("TotalWorkingYears")['Attrition'].value_counts(normalize=False).unstack()

total_working_years.plot(kind='bar', stacked='False',figsize=(8,5))

plt.title('Total Working Years of Experience')
plt.ylabel('Number of Employee')
plt.show()

# %%
#It is observed that freshers leave the company very likely so it's important that company creates a new policy to handle freshers so they don't leave the company from the start

# %%
# Filter employees who left the company (Attrition == 'Yes')
mi_yes = df[df['Attrition'] == 'Yes']['MonthlyIncome']

# Filter employees who didn't leave the company (Attrition == 'No')
mi_no = df[df['Attrition'] == 'No']['MonthlyIncome']

# Reset the index to align the data for concatenation
mi_yes = mi_yes.reset_index(drop=True)
mi_no = mi_no.reset_index(drop=True)

# Create a new DataFrame with MonthlyIncome of employees who left and didn't leave in separate columns
mi_comparison = pd.concat([mi_yes, mi_no], axis=1)
mi_comparison.columns = ['Yes', 'No']  # Rename columns
mi_comparison.head()
# Out:
#         Yes      No
# 0   41890.0  131160
# 1   58130.0  193280
# 2   57620.0   83210
# 3  103330.0   23420
# 4   68540.0   40710
#         Yes      No
# 0   41890.0  131160
# 1   58130.0  193280
# 2   57620.0   83210
# 3  103330.0   23420
# 4   68540.0   40710

# %%
#  box plot of Attrition w.r.t. monthly income  
# Assuming mi_comparison is your DataFrame containing MonthlyIncome of employees who left and didn't leave

# Plotting box plot
mi_comparison.plot(kind='box', figsize=(10, 7))

plt.title('Box plot of Monthly Income vs Attrition')
plt.ylabel('Monthly Income')
plt.xlabel('Attrition')

plt.xticks([1, 2], ['Yes', 'No'])  # Setting x-ticks as Yes and No
plt.show()

# %%
#   Employees who left their jobs tend to have low average monthly income than those who continued their job in the company

# %%
#  now we will do Analysis w.r.t. Departments

department = df[['Department','Attrition']]
department.head()
# Out:
#                Department Attrition
# 0                   Sales        No
# 1  Research & Development       Yes
# 2  Research & Development        No
# 3  Research & Development        No
# 4  Research & Development        No
#                Department Attrition
# 0                   Sales        No
# 1  Research & Development       Yes
# 2  Research & Development        No
# 3  Research & Development        No
# 4  Research & Development        No

# %%
department['Department'].value_counts()
# Out:
# Department
# Research & Development    2807
# Sales                     1307
# Human Resources            186
# Name: count, dtype: int64
# Department
# Research & Development    2807
# Sales                     1307
# Human Resources            186
# Name: count, dtype: int64

# %%
department['Department'].value_counts().plot(kind='pie',figsize=(15, 6),autopct='%1.1f%%', startangle=90, shadow=True, labels=None)   
plt.axis('equal') 
plt.legend(labels=department['Department'].unique(), loc='upper left')

# %%
dpar_Attrition = df.groupby("Department")['Attrition'].value_counts(normalize=False).unstack()
dpar_Attrition = dpar_Attrition.transpose()
dpar_Attrition
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                      132                    2364   1109
# Yes                      54                     443    198
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                      132                    2364   1109
# Yes                      54                     443    198

# %%
# Filter data for the specified departments
departments = ['Human Resources', 'Research & Development', 'Sales']
attrition_by_department = df[df['Department'].isin(departments)]

# Group by Department and Attrition, and calculate counts
attrition_counts = attrition_by_department.groupby(['Department', 'Attrition']).size().unstack()

# Plotting
attrition_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=360)
plt.legend(title='Attrition')
plt.show()

# %%
#  Here is the clear indication that Research & development has more Attrition than Sales and HR department

# %%
gender_a = df[['Gender', 'DistanceFromHome', 'Attrition']]
gender_a.head()
# Out:
#    Gender  DistanceFromHome Attrition
# 0  Female                 6        No
# 1  Female                10       Yes
# 2    Male                17        No
# 3    Male                 2        No
# 4    Male                10        No
#    Gender  DistanceFromHome Attrition
# 0  Female                 6        No
# 1  Female                10       Yes
# 2    Male                17        No
# 3    Male                 2        No
# 4    Male                10        No

# %%
gender_a['Gender'].value_counts()
# Out:
# Gender
# Male      2571
# Female    1729
# Name: count, dtype: int64
# Gender
# Male      2571
# Female    1729
# Name: count, dtype: int64

# %%
gender_a['Gender'].value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None)   
plt.axis('equal') 
plt.legend(labels=['Male', 'Female'], loc='upper left')

# %%
attrition_by_gender = gender_a.groupby("Gender")['Attrition'].value_counts(normalize=False).unstack()
attrition_by_gender = attrition_by_gender.transpose()
attrition_by_gender
# Out:
# Gender     Female  Male
# Attrition
# No           1464  2141
# Yes           265   430
# Gender     Female  Male
# Attrition
# No           1464  2141
# Yes           265   430

# %%
# Filter data for the specified genders
genders = ['Male', 'Female']
attrition_by_gender = df[df['Gender'].isin(genders)]

# Group by Gender and Attrition, and calculate counts
attrition_counts = attrition_by_gender.groupby(['Gender', 'Attrition']).size().unstack()

# Plotting
attrition_counts.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Attrition')
plt.show()

# %%
#   Here is the clear indication that Attrition in Males are higher than Female employees

# %%
# Now we Analyse Attrition w.r.t to Employees Marital Status

marital_status = df[['MaritalStatus', 'Attrition']]
marital_status.head()
# Out:
#   MaritalStatus Attrition
# 0       Married        No
# 1        Single       Yes
# 2       Married        No
# 3       Married        No
# 4        Single        No
#   MaritalStatus Attrition
# 0       Married        No
# 1        Single       Yes
# 2       Married        No
# 3       Married        No
# 4        Single        No

# %%
marital_status['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     1969
# Single      1382
# Divorced     949
# Name: count, dtype: int64
# MaritalStatus
# Married     1969
# Single      1382
# Divorced     949
# Name: count, dtype: int64

# %%
marital_status['MaritalStatus'].value_counts().plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None)   
plt.axis('equal') 
plt.legend(labels=['Married', 'Single', 'Divorced'], loc='upper left')

# %%
marital_status_analysis = marital_status.groupby("MaritalStatus")['Attrition'].value_counts(normalize=False).unstack()
marital_status_analysis = marital_status_analysis.transpose()
marital_status_analysis
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# No                  855     1718    1032
# Yes                  94      251     350
# MaritalStatus  Divorced  Married  Single
# Attrition
# No                  855     1718    1032
# Yes                  94      251     350

# %%
# Filter data for the specified marital statuses
marital_statuses = ['Married', 'Single', 'Divorced']
attrition_by_marital_status = df[df['MaritalStatus'].isin(marital_statuses)]

# Group by MaritalStatus and Attrition, and calculate counts
attrition_counts = attrition_by_marital_status.groupby(['MaritalStatus', 'Attrition']).size().unstack()

# Plotting
attrition_counts.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Attrition by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Attrition')
plt.show()

# %%
# Here is the Single people have more Attrition than married and divorced

# %%
#Model Preprocessing

from sklearn import preprocessing
import math
from sklearn.model_selection import train_test_split
from sklearn import metrics 

df.columns
# Out:
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating'], dtype='object')
# Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement', 'PerformanceRating'], dtype='object')

# %%
df.head(2)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  DistanceFromHome  Education EducationField  Gender  JobLevel                    JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51        No      Travel_Rarely                   Sales                 6          2  Life Sciences  Female         1  Healthcare Representative       Married         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
label_encoding = preprocessing.LabelEncoder()
categorial_variables = ['Attrition','BusinessTravel','Department','EducationField',
                        'Gender','JobRole','MaritalStatus']

# %%
for i in categorial_variables:
    df[i] = label_encoding.fit_transform(df[i])
df.head(5)
# Out:
#    EmployeeID  Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51          0               2           2                 6          2               1       0         1        0              1         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
df.corr()
# Out:
#                          EmployeeID       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  EducationField    Gender  JobLevel   JobRole  MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# EmployeeID                 1.000000  0.003651  -0.001707       -0.001545   -0.004107          0.003851  -0.012041       -0.003447 -0.014023 -0.002695  0.003395       0.005152       0.009136           -0.000349          -0.004508          -0.003896              -0.010225        0.000087                 0.002201              0.005617                 0.002042         0.000165        -0.005785        0.010275          -0.008336
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your dataframe stored in df
# Calculate correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap='coolwarm', annot=True, fmt=".1%", center=0, square=True, linewidths=.5)

# Rotate the tick labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

# Add title
plt.title('Correlation Heatmap with Percentage')

# Display the plot
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
target = df['Attrition']
train = df.drop('Attrition',axis = 1)
train.shape
# Out:
# (4300, 24)
# (4300, 24)

# %%
target.head(1)
# Out:
# 0    0
# Name: Attrition, dtype: int32
# 0    0
# Name: Attrition, dtype: int32

# %%
train.head(1)
# Out:
#    EmployeeID  Age  BusinessTravel  Department  DistanceFromHome  Education  EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating
# 0           1   51               2           2                 6          2               1       0         1        0              1         131160                 1.0                 11                1.0                      6               1                        0                     0                      3.0              4.0              2.0               3                  3
# ...

# %%
# Here we will classify through Models


train_accuracy = []
test_accuracy = []
models = ['Logistic Regression','SVM','KNN','Decision Tree','K Means Clustering']

# %%
#Defining a function which will give us train and test accuracy for each classifier.
def train_test_error(y_train,y_test):
    train_error = ((y_train==Y_train).sum())/len(y_train)*100
    test_error = ((y_test==Y_test).sum())/len(Y_test)*100
    train_accuracy.append(train_error)
    test_accuracy.append(test_error)
    print('{}'.format(train_error) + " is the train accuracy")
    print('{}'.format(test_error) + " is the test accuracy")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(train, target, test_size=0.25, random_state=42)

# %%
#Logistic Regression model

from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,Y_train)
train_predict = log_reg.predict(X_train)
test_predict = log_reg.predict(X_test)
y_prob = log_reg.predict(train)
y_pred = np.where(y_prob > 0.5, 1, 0)
train_test_error(train_predict , test_predict)
# Out:
# 83.78294573643412 is the train accuracy
# 84.0 is the test accuracy
# 83.78294573643412 is the train accuracy
# 84.0 is the test accuracy

# %%
#SVM Classifier

from sklearn import svm
SVM = svm.SVC(probability=True)
SVM.fit(X_train,Y_train)
train_predict = SVM.predict(X_train)
test_predict = SVM.predict(X_test)
train_test_error(train_predict , test_predict)
# Out:
# 83.78294573643412 is the train accuracy
# 84.0 is the test accuracy
# 83.78294573643412 is the train accuracy
# 84.0 is the test accuracy

# %%
#KNN Classifier

from sklearn import neighbors
n_neighbors = 15
knn = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
knn.fit(X_train,Y_train)
train_predict = knn.predict(X_train)
test_predict = knn.predict(X_test)
train_test_error(train_predict , test_predict)
# Out:
# 100.0 is the train accuracy
# 81.86046511627907 is the test accuracy
# 100.0 is the train accuracy
# 81.86046511627907 is the test accuracy

# %%
#Decision Tree Classifier

from sklearn import tree
dec = tree.DecisionTreeClassifier()
dec.fit(X_train,Y_train)
train_predict = dec.predict(X_train)
test_predict = dec.predict(X_test)
train_test_error(train_predict , test_predict)
# Out:
# 100.0 is the train accuracy
# 98.13953488372093 is the test accuracy
# 100.0 is the train accuracy
# 98.13953488372093 is the test accuracy

# %%
#K-Means Clustering 

from sklearn.cluster import KMeans
kms = KMeans(n_clusters=2, random_state=1)
kms.fit(X_train,Y_train)
train_predict = kms.predict(X_train)
test_predict = kms.predict(X_test)
train_test_error(train_predict,test_predict)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 66.94573643410853 is the train accuracy
# 68.46511627906978 is the test accuracy
# 66.94573643410853 is the train accuracy
# 68.46511627906978 is the test accuracy

# %%
results = pd.DataFrame({"Test Accuracy" : test_accuracy , "Train Accuracy" : train_accuracy} , index = models)

# %%
results
# Out:
#                      Test Accuracy  Train Accuracy
# Logistic Regression      84.000000       83.782946
# SVM                      84.000000       83.782946
# KNN                      81.860465      100.000000
# Decision Tree            98.139535      100.000000
# K Means Clustering       68.465116       66.945736
#                      Test Accuracy  Train Accuracy
# Logistic Regression      84.000000       83.782946
# SVM                      84.000000       83.782946
# KNN                      81.860465      100.000000
# Decision Tree            98.139535      100.000000
# K Means Clustering       68.465116       66.945736

# %%
# now we are choosing the Logistic regression model for future Prediction 


from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,log_reg.predict(X_test))

TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

print(cm)
print('model test acuuracy = {}' . format ((TP + TN)/(TP + TN + FN + FP)))
# Out:
# [[903   0]
#  [172   0]]
# model test acuuracy = 0.84
# [[903   0]
#  [172   0]]
# model test acuuracy = 0.84
